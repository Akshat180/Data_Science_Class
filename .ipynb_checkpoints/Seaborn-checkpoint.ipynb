# %%
import numpy as np
import  pandas as pd
import seaborn as sns

# %%
n = pd.read_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\Nba.csv')

# %%
nc = n.corr(numeric_only = True)
nc
# Out:
#           Number       Age    Weight    Salary
# Number  1.000000  0.028724  0.206921 -0.112386
# Age     0.028724  1.000000  0.087183  0.213459
# Weight  0.206921  0.087183  1.000000  0.138321
# Salary -0.112386  0.213459  0.138321  1.000000

# %% [markdown]
# # HeatMap

# %%
sns.heatmap(nc)
# Out:
# <Axes: >

# %%
sns.heatmap(nc,annot =True)
# Out:
# <Axes: >

# %%
sns.heatmap(nc,annot =True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Displot

# %%
sns.displot(x = 'Age', data = n, bins = 10, kde = True)  # kde = Kernel Density Estimation

# %%
sns.countplot(x = 'Position', data = n)
# Out:
# <Axes: xlabel='Position', ylabel='count'>

# %%
n.Position.value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Team', data = n)
# Out:
# <Axes: xlabel='Team', ylabel='count'>

# %%
sns.countplot?

# %%
sns.countplot(y = 'Team', data = n)
# Out:
# <Axes: xlabel='count', ylabel='Team'>

# %%
sns.countplot(x = 'Position', data = n, palette = ['r'])
# Out:
# <Axes: xlabel='Position', ylabel='count'>

# %%
sns.jointplot(x = 'Age', y = 'Salary', data = n, hue = 'Position')

# %%
n[n.Age == 40]
# Out:
#               Name                    Team  Number Position  Age Height
# 298     Tim Duncan       San Antonio Spurs      21        C   40   6-11  \
# 304   Andre Miller       San Antonio Spurs      24       PG   40    6-3
# 400  Kevin Garnett  Minnesota Timberwolves      21       PF   40   6-11
#
#      Weight      College     Salary
# 298     250  Wake Forest  5250000.0
# 304     200         Utah   250750.0
# 400     240          NaN  8500000.0

# %%
sns.jointplot(x = 'Age', y = 'Salary', data = n, kind = 'hex')

# %%
sns.jointplot(x = 'Age', y = 'Salary', data = n, kind = 'kde')

# %%
sns.jointplot(x = 'Age', y = 'Salary', data = n, kind = 'hist')

# %%
sns.barplot(x = 'Position', y = 'Age', data = n)
# Out:
# <Axes: xlabel='Position', ylabel='Age'>

# %%
sns.barplot?

# %%
sns.violinplot(x = 'Position', y = 'Age', data = n)
# Out:
# <Axes: xlabel='Position', ylabel='Age'>
