# %%
import pandas as pd
n = pd.read_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science Course\Data\Nba.csv')

# %%
n
# Out:
#               Name            Team  Number Position  Age Height  Weight
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2     180  \
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2     John Holland  Boston Celtics      30       SG   27    6-5     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3     203
# 454      Raul Neto       Utah Jazz      25       PG   24    6-1     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26    7-3     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
n.query("Age > 30")
# Out:
#                 Name                    Team  Number Position  Age Height
# 19      Jarrett Jack           Brooklyn Nets       2       PG   32    6-3  \
# 31      Lou Amundson         New York Knicks      17       PF   33    6-9
# 33   Carmelo Anthony         New York Knicks       7       SF   32    6-8
# 34     Jose Calderon         New York Knicks       3       PG   34    6-3
# 43     Sasha Vujacic         New York Knicks      18       SG   32    6-7
# ..               ...                     ...     ...      ...  ...    ...
# 406  Tayshaun Prince  Minnesota Timberwolves      12       SF   36    6-9
# 413    Nick Collison   Oklahoma City Thunder       4       PF   35   6-10
# 415       Randy Foye   Oklahoma City Thunder       6       SG   32    6-4
# 420    Nazr Mohammed   Oklahoma City Thunder      13        C   38   6-10
# 434      Chris Kaman  Portland Trail Blazers      35        C   34    7-0
#
#      Weight           College      Salary
# ...

# %%
n["Age"].dtype
# Out:
# dtype('int64')

# %%
n.select_dtypes(include= 'int64')
# Out:
#      Number  Age  Weight
# 0         0   25     180
# 1        99   25     235
# 2        30   27     205
# 3        28   22     185
# 4         8   29     231
# ..      ...  ...     ...
# 452      41   20     234
# 453       8   26     203
# 454      25   24     179
# 455      21   26     256
# 456      24   26     231
#
# [457 rows x 3 columns]

# %%
import numpy as np
random_col = np.random.randint(100, size=len(n))
n.insert(3, 'random_col', random_col)
n
# Out:
#               Name            Team  Number  random_col Position  Age Height
# 0    Avery Bradley  Boston Celtics       0          74       PG   25    6-2  \
# 1      Jae Crowder  Boston Celtics      99          81       SF   25    6-6
# 2     John Holland  Boston Celtics      30          93       SG   27    6-5
# 3      R.J. Hunter  Boston Celtics      28          25       SG   22    6-5
# 4    Jonas Jerebko  Boston Celtics       8          96       PF   29   6-10
# ..             ...             ...     ...         ...      ...  ...    ...
# 452     Trey Lyles       Utah Jazz      41          60       PF   20   6-10
# 453   Shelvin Mack       Utah Jazz       8          37       PG   26    6-3
# 454      Raul Neto       Utah Jazz      25          49       PG   24    6-1
# 455   Tibor Pleiss       Utah Jazz      21           7        C   26    7-3
# 456    Jeff Withey       Utah Jazz      24           6        C   26    7-0
#
#      Weight            College     Salary
# ...

# %%
len(random_col)
# Out:
# 457

# %%
n[['Height', 'Age']].cumsum()
# Out:
#                                                 Height    Age
# 0                                                  6-2     25
# 1                                               6-26-6     50
# 2                                            6-26-66-5     77
# 3                                         6-26-66-56-5     99
# 4                                     6-26-66-56-56-10    128
# ..                                                 ...    ...
# 452  6-26-66-56-56-106-96-87-06-26-46-95-96-76-67-0...  12209
# 453  6-26-66-56-56-106-96-87-06-26-46-95-96-76-67-0...  12235
# 454  6-26-66-56-56-106-96-87-06-26-46-95-96-76-67-0...  12259
# 455  6-26-66-56-56-106-96-87-06-26-46-95-96-76-67-0...  12285
# 456  6-26-66-56-56-106-96-87-06-26-46-95-96-76-67-0...  12311
#
# [457 rows x 2 columns]

# %%
n.sample(n= 10)
# Out:
#                  Name                    Team  Number  random_col Position
# 126      John Jenkins            Phoenix Suns      23          67       SG  \
# 154     Mike Dunleavy           Chicago Bulls      34          91       SG
# 175      Jordan McRae     Cleveland Cavaliers      12          52       SG
# 9        Marcus Smart          Boston Celtics      36          19       PG
# 400     Kevin Garnett  Minnesota Timberwolves      21          29       PF
# 98     DeAndre Jordan    Los Angeles Clippers       6          80        C
# 44   Derrick Williams         New York Knicks      23          60       PF
# 204       Ian Mahinmi          Indiana Pacers      28          94        C
# 57          Ish Smith      Philadelphia 76ers       1          85       PG
# 30      Arron Afflalo         New York Knicks       4          21       SG
#
#      Age Height  Weight         College      Salary
# 126   25    6-4     215      Vanderbilt    981348.0
# ...

# %%
n['random_col'].where(n.random_col> 50,"jo cahiye")
# Out:
# 0             74
# 1             81
# 2             93
# 3      jo cahiye
# 4             96
#          ...
# 452           60
# 453    jo cahiye
# 454    jo cahiye
# 455    jo cahiye
# 456    jo cahiye
# Name: random_col, Length: 457, dtype: object

# %%
n.nunique()
# it tells the number of nunique
# Out:
# Name          457
# Team           30
# Number         53
# random_col     99
# Position        5
# Age            22
# Height         18
# Weight         87
# College       118
# Salary        309
# dtype: int64

# %%
n.Age.unique()
# Out:
# array([25, 27, 22, 29, 21, 24, 20, 26, 28, 32, 23, 30, 33, 34, 37, 36, 31,
#        38, 39, 19, 35, 40], dtype=int64)

# %%
n['rank_calc'] = n["Salary"].rank()
n # this sort on the basis we give and provide the value
# Out:
#               Name            Team  Number  random_col Position  Age Height
# 0    Avery Bradley  Boston Celtics       0          74       PG   25    6-2  \
# 1      Jae Crowder  Boston Celtics      99          81       SF   25    6-6
# 2     John Holland  Boston Celtics      30          93       SG   27    6-5
# 3      R.J. Hunter  Boston Celtics      28          25       SG   22    6-5
# 4    Jonas Jerebko  Boston Celtics       8          96       PF   29   6-10
# ..             ...             ...     ...         ...      ...  ...    ...
# 452     Trey Lyles       Utah Jazz      41          60       PF   20   6-10
# 453   Shelvin Mack       Utah Jazz       8          37       PG   26    6-3
# 454      Raul Neto       Utah Jazz      25          49       PG   24    6-1
# 455   Tibor Pleiss       Utah Jazz      21           7        C   26    7-3
# 456    Jeff Withey       Utah Jazz      24           6        C   26    7-0
#
#      Weight            College     Salary  rank_calc
# ...

# %%
col = ['PG','SG']
n[n.Position.isin(col)]
# Out:
#               Name            Team  Number  random_col Position  Age Height
# 0    Avery Bradley  Boston Celtics       0          74       PG   25    6-2  \
# 2     John Holland  Boston Celtics      30          93       SG   27    6-5
# 3      R.J. Hunter  Boston Celtics      28          25       SG   22    6-5
# 8     Terry Rozier  Boston Celtics      12          20       PG   22    6-2
# 9     Marcus Smart  Boston Celtics      36          19       PG   22    6-4
# ..             ...             ...     ...         ...      ...  ...    ...
# 444     Alec Burks       Utah Jazz      10          85       SG   24    6-6
# 445     Dante Exum       Utah Jazz      11          39       PG   20    6-6
# 449    Rodney Hood       Utah Jazz       5          42       SG   23    6-8
# 453   Shelvin Mack       Utah Jazz       8          37       PG   26    6-3
# 454      Raul Neto       Utah Jazz      25          49       PG   24    6-1
#
#      Weight            College     Salary  rank_calc
# ...

# %%
n3= n.replace('PG','LA')
n3
# Out:
#               Name            Team  Number  random_col Position  Age Height
# 0    Avery Bradley  Boston Celtics       0          74       LA   25    6-2  \
# 1      Jae Crowder  Boston Celtics      99          81       SF   25    6-6
# 2     John Holland  Boston Celtics      30          93       SG   27    6-5
# 3      R.J. Hunter  Boston Celtics      28          25       SG   22    6-5
# 4    Jonas Jerebko  Boston Celtics       8          96       PF   29   6-10
# ..             ...             ...     ...         ...      ...  ...    ...
# 452     Trey Lyles       Utah Jazz      41          60       PF   20   6-10
# 453   Shelvin Mack       Utah Jazz       8          37       LA   26    6-3
# 454      Raul Neto       Utah Jazz      25          49       LA   24    6-1
# 455   Tibor Pleiss       Utah Jazz      21           7        C   26    7-3
# 456    Jeff Withey       Utah Jazz      24           6        C   26    7-0
#
#      Weight            College     Salary  rank_calc
# ...

# %%
n2=n.rename(columns = {"Weight": "Weight (kg)", "Height": "Height (cm)"})
n2
# Out:
#               Name            Team  Number  random_col Position  Age
# 0    Avery Bradley  Boston Celtics       0          74       PG   25  \
# 1      Jae Crowder  Boston Celtics      99          81       SF   25
# 2     John Holland  Boston Celtics      30          93       SG   27
# 3      R.J. Hunter  Boston Celtics      28          25       SG   22
# 4    Jonas Jerebko  Boston Celtics       8          96       PF   29
# ..             ...             ...     ...         ...      ...  ...
# 452     Trey Lyles       Utah Jazz      41          60       PF   20
# 453   Shelvin Mack       Utah Jazz       8          37       PG   26
# 454      Raul Neto       Utah Jazz      25          49       PG   24
# 455   Tibor Pleiss       Utah Jazz      21           7        C   26
# 456    Jeff Withey       Utah Jazz      24           6        C   26
#
#     Height (cm)  Weight (kg)            College     Salary  rank_calc
# ...

# %%
n1 = n.fillna(5) # it fill the empty value you want the value with
n1
# Out:
#               Name            Team  Number  random_col Position  Age Height
# 0    Avery Bradley  Boston Celtics       0          74       PG   25    6-2  \
# 1      Jae Crowder  Boston Celtics      99          81       SF   25    6-6
# 2     John Holland  Boston Celtics      30          93       SG   27    6-5
# 3      R.J. Hunter  Boston Celtics      28          25       SG   22    6-5
# 4    Jonas Jerebko  Boston Celtics       8          96       PF   29   6-10
# ..             ...             ...     ...         ...      ...  ...    ...
# 452     Trey Lyles       Utah Jazz      41          60       PF   20   6-10
# 453   Shelvin Mack       Utah Jazz       8          37       PG   26    6-3
# 454      Raul Neto       Utah Jazz      25          49       PG   24    6-1
# 455   Tibor Pleiss       Utah Jazz      21           7        C   26    7-3
# 456    Jeff Withey       Utah Jazz      24           6        C   26    7-0
#
#      Weight            College     Salary  rank_calc
# ...

# %%
n.groupby("Age")['Number'].sum()
# Out:
# Age
# 19     21
# 20    327
# 21    348
# 22    375
# 23    807
# 24    774
# 25    894
# 26    622
# 27    766
# 28    612
# 29    473
# 30    373
# 31    279
# 32    167
# 33    330
# 34    235
# 35    177
# 36    197
# 37    114
# 38     98
# 39     24
# 40     66
# Name: Number, dtype: int64

# %%
n.Salary.pct_change() # tell the percentage change
# Out:
# 0           NaN
# 1     -0.120851
# 2      0.000000
# 3     -0.830986
# 4      3.352974
#          ...
# 452    1.282371
# 453    0.086406
# 454   -0.630137
# 455    2.222222
# 456   -0.673353
# Name: Salary, Length: 457, dtype: float64

# %%
n.count(0) # yeh sbke total deta hai
# Out:
# Name          457
# Team          457
# Number        457
# random_col    457
# Position      457
# Age           457
# Height        457
# Weight        457
# College       373
# Salary        446
# rank_calc     446
# dtype: int64

# %%
n['Age'].value_counts() #yeh batata hai ki kitni age mai kitne log hai
# Out:
# Age
# 24    47
# 25    45
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
pd.crosstab(n.Team,n.Age).T
# Out:
# Team  Atlanta Hawks  Boston Celtics  Brooklyn Nets  Charlotte Hornets
# Age
# 19                0               0              0                  0  \
# 20                0               1              0                  0
# 21                0               1              2                  1
# 22                1               3              1                  1
# 23                0               0              1                  2
# 24                4               1              1                  2
# 25                0               3              1                  0
# 26                1               1              3                  1
# 27                2               3              2                  3
# 28                0               0              3                  1
# 29                0               2              0                  1
# 30                1               0              0                  2
# ...

# %%
n2[['Team','Age']].value_counts()
# Out:
# Team                   Age
# Philadelphia 76ers     22     5
# Oklahoma City Thunder  24     5
# Utah Jazz              26     5
# Detroit Pistons        23     4
# Milwaukee Bucks        21     4
#                              ..
# Los Angeles Lakers     33     1
#                        36     1
#                        37     1
# Memphis Grizzlies      21     1
# Washington Wizards     34     1
# Name: count, Length: 288, dtype: int64

# %%
n.Position.value_counts(normalize = True)*100 #this gives the percentage
# Out:
# Position
# SG    22.319475
# PF    21.881838
# PG    20.131291
# SF    18.599562
# C     17.067834
# Name: proportion, dtype: float64

# %%
n.nlargest(5, "Age")
# Out:
#                Name                    Team  Number  random_col Position  Age
# 298      Tim Duncan       San Antonio Spurs      21          28        C   40  \
# 304    Andre Miller       San Antonio Spurs      24          48       PG   40
# 400   Kevin Garnett  Minnesota Timberwolves      21          29       PF   40
# 102  Pablo Prigioni    Los Angeles Clippers       9          79       PG   39
# 261    Vince Carter       Memphis Grizzlies      15          60       SG   39
#
#     Height  Weight         College     Salary  rank_calc
# 298   6-11     250     Wake Forest  5250000.0      312.0
# 304    6-3     200            Utah   250750.0       19.0
# 400   6-11     240             NaN  8500000.0      364.0
# 102    6-3     185             NaN   947726.0       96.0
# 261    6-6     220  North Carolina  4088019.0      279.0

# %%
n.nsmallest(5, "Age")
# Out:
#                    Name                Team  Number  random_col Position  Age
# 122        Devin Booker        Phoenix Suns       1          36       SG   19  \
# 226       Rashad Vaughn     Milwaukee Bucks      20          91       SG   19
# 13          James Young      Boston Celtics      13          41       SG   20
# 40   Kristaps Porzingis     New York Knicks       6          81       PF   20
# 56        Jahlil Okafor  Philadelphia 76ers       8          23        C   20
#
#     Height  Weight   College     Salary  rank_calc
# 122    6-6     206  Kentucky  2127840.0      190.0
# 226    6-6     202      UNLV  1733040.0      172.0
# 13     6-6     215  Kentucky  1749840.0      173.0
# 40     7-3     240       NaN  4131720.0      280.0
# 56    6-11     275      Duke  4582680.0      292.0

# %%
n['Age'].describe()
# Out:
# count    457.000000
# mean      26.938731
# std        4.404016
# min       19.000000
# 25%       24.000000
# 50%       26.000000
# 75%       30.000000
# max       40.000000
# Name: Age, dtype: float64

# %%
pd.cut(n.Age , bins = 3 , right = True)  # 3 mtlb data ko 3 part mai divide krna
# Out:
# 0      (18.979, 26.0]
# 1      (18.979, 26.0]
# 2        (26.0, 33.0]
# 3      (18.979, 26.0]
# 4        (26.0, 33.0]
#             ...
# 452    (18.979, 26.0]
# 453    (18.979, 26.0]
# 454    (18.979, 26.0]
# 455    (18.979, 26.0]
# 456    (18.979, 26.0]
# Name: Age, Length: 457, dtype: category
# Categories (3, interval[float64, right]): [(18.979, 26.0] < (26.0, 33.0] < (33.0, 40.0]]

# %%
pd.cut(n.Age , bins = 3 , right = False , retbins = True) # bins divide the data in parts not have same number of values in 
#                                                            every bins
# Out:
# (0      [19.0, 26.0)
#  1      [19.0, 26.0)
#  2      [26.0, 33.0)
#  3      [19.0, 26.0)
#  4      [26.0, 33.0)
#             ...
#  452    [19.0, 26.0)
#  453    [26.0, 33.0)
#  454    [19.0, 26.0)
#  455    [26.0, 33.0)
#  456    [26.0, 33.0)
#  Name: Age, Length: 457, dtype: category
#  Categories (3, interval[float64, left]): [[19.0, 26.0) < [26.0, 33.0) < [33.0, 40.021)],
#  array([19.   , 26.   , 33.   , 40.021]))

# %%
pd.cut(n.Age , bins = 3 , right = False , retbins = True , labels = ['new','medium','old'])
# Out:
# (0         new
#  1         new
#  2      medium
#  3         new
#  4      medium
#          ...
#  452       new
#  453    medium
#  454       new
#  455    medium
#  456    medium
#  Name: Age, Length: 457, dtype: category
#  Categories (3, object): ['new' < 'medium' < 'old'],
#  array([19.   , 26.   , 33.   , 40.021]))

# %%
pd.qcut(n.Age,q=3)   #q is quantile    we use to have same number or values in every Quatile
# Out:
# 0        (24.0, 28.0]
# 1        (24.0, 28.0]
# 2        (24.0, 28.0]
# 3      (18.999, 24.0]
# 4        (28.0, 40.0]
#             ...
# 452    (18.999, 24.0]
# 453      (24.0, 28.0]
# 454    (18.999, 24.0]
# 455      (24.0, 28.0]
# 456      (24.0, 28.0]
# Name: Age, Length: 457, dtype: category
# Categories (3, interval[float64, right]): [(18.999, 24.0] < (24.0, 28.0] < (28.0, 40.0]]

# %%
df1 = pd.DataFrame({"city": ['A', 'B', 'C'],
                   "day1": [22, 25, 21],
                   'day2':[31, 12, 67],
                   'day3': [27, 20, 15],
                   'day4': [34, 37, [41, 45, 67, 90, 21]],
                   'day5': [23, 54, 36]})
df1
# Out:
#   city  day1  day2  day3                  day4  day5
# 0    A    22    31    27                    34    23
# 1    B    25    12    20                    37    54
# 2    C    21    67    15  [41, 45, 67, 90, 21]    36

# %%
df2 = df1.explode('day4').reset_index(drop=True)
df2
# Out:
#   city  day1  day2  day3 day4  day5
# 0    A    22    31    27   34    23
# 1    B    25    12    20   37    54
# 2    C    21    67    15   41    36
# 3    C    21    67    15   45    36
# 4    C    21    67    15   67    36
# 5    C    21    67    15   90    36
# 6    C    21    67    15   21    36

# %%
df2.unstack()
# Out:
# city  0     A
#       1     B
#       2     C
#       3     C
#       4     C
#       5     C
#       6     C
# day1  0    22
#       1    25
#       2    21
#       3    21
#       4    21
#       5    21
#       6    21
# day2  0    31
#       1    12
#       2    67
#       3    67
#       4    67
#       5    67
#       6    67
# day3  0    27
#       1    20
#       2    15
#       3    15
#       4    15
#       5    15
#       6    15
# day4  0    34
#       1    37
#       2    41
#       3    45
#       4    67
#       5    90
#       6    21
# day5  0    23
#       1    54
#       2    36
#       3    36
#       4    36
#       5    36
#       6    36
# dtype: object

# %%
n[n.rank_calc == 1]
# Out:
#                       Name             Team  Number  random_col Position  Age
# 32  Thanasis Antetokounmpo  New York Knicks      43          86       SF   23  \
#
#    Height  Weight College   Salary  rank_calc
# 32    6-7     205     NaN  30888.0        1.0

# %%
n.sample(5) # this gives any 5 data
# Out:
#                 Name                    Team  Number  random_col Position
# 405   Nikola Pekovic  Minnesota Timberwolves      14          55        C  \
# 337  Marvin Williams       Charlotte Hornets       2          71       PF
# 253   K.J. McDaniels         Houston Rockets      32           1       SG
# 50      Jerami Grant      Philadelphia 76ers      39           6       SF
# 158   Justin Holiday           Chicago Bulls       7          70       SG
#
#      Age Height  Weight         College      Salary  rank_calc
# 405   30   6-11     307             NaN  12100000.0      393.0
# 337   29    6-9     237  North Carolina   7000000.0      341.5
# 253   23    6-6     205         Clemson   3189794.0      247.0
# 50    22    6-8     210        Syracuse    845059.0       53.5
# 158   27    6-6     185      Washington    947276.0       80.0

# %%
n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        457 non-null    object
#  1   Team        457 non-null    object
#  2   Number      457 non-null    int64
#  3   random_col  457 non-null    int32
#  4   Position    457 non-null    object
#  5   Age         457 non-null    int64
#  6   Height      457 non-null    object
#  7   Weight      457 non-null    int64
#  8   College     373 non-null    object
#  9   Salary      446 non-null    float64
#  10  rank_calc   446 non-null    float64
# dtypes: float64(2), int32(1), int64(3), object(5)
# memory usage: 37.6+ KB

# %%
n.describe()
# This function returns descriptive statistics about the data. 
# This includes minimum, maximum, mean (central tendency), standard deviation (dispersion)
# of the values in numerical columns, and the count of all non-null values in the data, as shown below.
# Out:
#            Number  random_col         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  457.000000  4.460000e+02  \
# mean    17.678337   49.958425   26.938731  221.522976  4.842684e+06
# std     15.966090   29.027218    4.404016   26.368343  5.229238e+06
# min      0.000000    0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   52.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   74.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   99.000000   40.000000  307.000000  2.500000e+07
#
#         rank_calc
# count  446.000000
# mean   223.500000
# std    128.864832
# min      1.000000
# 25%    112.250000
# 50%    223.500000
# 75%    334.500000
# max    446.000000

# %%
n.query("Age > 24")
# This function is used to query the DataFrame based on an expression.
# An expression can be as simple as a single condition and as complex as a combination of multiple conditions.
# Out:
#               Name            Team  Number  random_col Position  Age Height
# 0    Avery Bradley  Boston Celtics       0          74       PG   25    6-2  \
# 1      Jae Crowder  Boston Celtics      99          81       SF   25    6-6
# 2     John Holland  Boston Celtics      30          93       SG   27    6-5
# 4    Jonas Jerebko  Boston Celtics       8          96       PF   29   6-10
# 5     Amir Johnson  Boston Celtics      90          73       PF   29    6-9
# ..             ...             ...     ...         ...      ...  ...    ...
# 450     Joe Ingles       Utah Jazz       2          82       SF   28    6-8
# 451  Chris Johnson       Utah Jazz      23          69       SF   26    6-6
# 453   Shelvin Mack       Utah Jazz       8          37       PG   26    6-3
# 455   Tibor Pleiss       Utah Jazz      21           7        C   26    7-3
# 456    Jeff Withey       Utah Jazz      24           6        C   26    7-0
#
#      Weight            College      Salary  rank_calc
# ...

# %%
n4= n.sort_values('Age')
n4
# Out:
#                    Name                    Team  Number  random_col Position
# 226       Rashad Vaughn         Milwaukee Bucks      20          91       SG  \
# 122        Devin Booker            Phoenix Suns       1          36       SG
# 40   Kristaps Porzingis         New York Knicks       6          81       PF
# 401          Tyus Jones  Minnesota Timberwolves       1          38       PG
# 427     Cliff Alexander  Portland Trail Blazers      34          90       PF
# ..                  ...                     ...     ...         ...      ...
# 261        Vince Carter       Memphis Grizzlies      15          60       SG
# 102      Pablo Prigioni    Los Angeles Clippers       9          79       PG
# 298          Tim Duncan       San Antonio Spurs      21          28        C
# 400       Kevin Garnett  Minnesota Timberwolves      21          29       PF
# 304        Andre Miller       San Antonio Spurs      24          48       PG
#
# ...

# %%
n5 = n.set_index('Name')

# %%
n5.loc["Tyus Jones"]
# Out:
# Team          Minnesota Timberwolves
# Number                             1
# random_col                        38
# Position                          PG
# Age                               20
# Height                           6-2
# Weight                           195
# College                         Duke
# Salary                     1282080.0
# rank_calc                      142.0
# Name: Tyus Jones, dtype: object

# %%
n.loc[10:20:2]
# Out:
#                        Name            Team  Number  random_col Position  Age
# 10          Jared Sullinger  Boston Celtics       7          88        C   24  \
# 12              Evan Turner  Boston Celtics      11          77       SG   27
# 14             Tyler Zeller  Boston Celtics      44          39        C   26
# 16             Markel Brown   Brooklyn Nets      22          93       SG   24
# 18  Rondae Hollis-Jefferson   Brooklyn Nets      24          16       SG   21
# 20           Sergey Karasev   Brooklyn Nets      10           2       SG   22
#
#    Height  Weight         College     Salary  rank_calc
# 10    6-9     260      Ohio State  2569260.0      214.0
# 12    6-7     220      Ohio State  3425510.0      255.5
# 14    7-0     253  North Carolina  2616975.0      216.0
# 16    6-3     190  Oklahoma State   845059.0       53.5
# 18    6-7     220         Arizona  1335480.0      147.0
# 20    6-7     208             NaN  1599840.0      165.0

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 n.iloc[["Age"],[40,66]]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
#    1593 def _getitem_tuple(self, tup: tuple):
# -> 1594     tup = self._validate_tuple_indexer(tup)
#    1595     with suppress(IndexingError):
#    1596         return self._getitem_lowerdim(tup)
#
# ...
